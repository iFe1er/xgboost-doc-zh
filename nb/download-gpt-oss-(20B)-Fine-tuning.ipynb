# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth your local device, follow [our guide](https://docs.unsloth.ai/get-started/install-and-update). This notebook is licensed [LGPL-3.0](https://github.com/unslothai/notebooks?tab=LGPL-3.0-1-ov-file#readme).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# Long-Context GRPO for reinforcement learning — train stably at massive sequence lengths. Fine-tune models with up to 7x more context length efficiently. [Read Blog](https://unsloth.ai/docs/new/grpo-long-context)
#
# 3× faster training with optimized sequence packing — higher throughput with no quality loss.[Read Blog](https://unsloth.ai/docs/new/3x-faster-training-packing)
#
# 500k context-length fine-tuning — push long-context models further with memory-efficient training. [Read Blog](https://unsloth.ai/docs/new/500k-context-length-fine-tuning)
#
# Introducing FP8 precision training for faster RL inference. [Read Blog](https://docs.unsloth.ai/new/fp8-reinforcement-learning).
#
# Unsloth's [Docker image](https://hub.docker.com/r/unsloth/unsloth) is here! Start training with no setup & environment issues. [Read our Guide](https://docs.unsloth.ai/new/how-to-train-llms-with-unsloth-and-docker).
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# !pip install git+https://github.com/foyoux/aligo.git
# Out:
# Collecting git+https://github.com/foyoux/aligo.git
#   Cloning https://github.com/foyoux/aligo.git to /tmp/pip-req-build-t9wkanwg
#   Running command git clone --filter=blob:none --quiet https://github.com/foyoux/aligo.git /tmp/pip-req-build-t9wkanwg
#   Resolved https://github.com/foyoux/aligo.git to commit b65af9be9d34e21fc0a36646b24dcd62fd7ad21c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting datclass>=0.2.22 (from aligo==0.0.1)
#   Downloading datclass-0.2.28-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: requests>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from aligo==0.0.1) (2.32.4)
# Collecting qrcode[pil] (from aligo==0.0.1)
#   Downloading qrcode-8.2-py3-none-any.whl.metadata (17 kB)
# Collecting coloredlogs (from aligo==0.0.1)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tqdm>=4.50.0 in /usr/local/lib/python3.12/dist-packages (from aligo==0.0.1) (4.67.1)
# Collecting qrcode_terminal (from aligo==0.0.1)
#   Downloading qrcode-terminal-0.8.tar.gz (1.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.9.0->aligo==0.0.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.9.0->aligo==0.0.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.9.0->aligo==0.0.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.9.0->aligo==0.0.1) (2026.1.4)
# Collecting humanfriendly>=9.1 (from coloredlogs->aligo==0.0.1)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from qrcode_terminal->aligo==0.0.1) (11.3.0)
# Downloading datclass-0.2.28-py3-none-any.whl (12 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.1 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.3 MB/s eta 0:00:00
# Downloading qrcode-8.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.8 MB/s eta 0:00:00
# Building wheels for collected packages: aligo, qrcode_terminal
#   Building wheel for aligo (pyproject.toml) ... done
#   Created wheel for aligo: filename=aligo-0.0.1-py3-none-any.whl size=141187 sha256=687341d2f51ca7d554d32289162a17e28020010b3f9021e8eb3d413d257472ab
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t68nuh90/wheels/8d/31/64/628131a3c63e908bb3eb2a94fed402c1f5769722868254b52b
#   Building wheel for qrcode_terminal (setup.py) ... done
#   Created wheel for qrcode_terminal: filename=qrcode_terminal-0.8-py3-none-any.whl size=2614 sha256=c57ba8bc9149245b22b022cb71dbed58c0ee7b75a320f03a15a5e6d83bdceca0
#   Stored in directory: /root/.cache/pip/wheels/85/5d/55/46b47c3b747fceec93872da9dcac288594a8c067e57573fb62
# Successfully built aligo qrcode_terminal
# Installing collected packages: qrcode, humanfriendly, datclass, qrcode_terminal, coloredlogs, aligo
# Successfully installed aligo-0.0.1 coloredlogs-15.0.1 datclass-0.2.28 humanfriendly-10.0 qrcode-8.2 qrcode_terminal-0.8

# %%
from aligo import Aligo
ali = Aligo()  # 第一次使用，会弹出二维码，供扫描登录
# Out:
# 07:04:08.631 aligo.INFO Config /root/.aligo/aligo.json
# 07:04:08.632 aligo.INFO 日志等级 DEBUG
# 07:04:08.634 aligo.INFO aligo 版本 0.0.1
# 07:04:08.635 aligo.INFO 类 Unix 操作系统
# 07:04:08.636 aligo.INFO 登录方式 扫描二维码
# 07:04:08.637 aligo.INFO 开始登录
# 07:04:08.639 aligo.DEBUG Starting new HTTPS connection (1): auth.aliyundrive.com:443
# 07:04:09.713 aligo.DEBUG https://auth.aliyundrive.com:443 "GET /v2/oauth/authorize?login_type=custom&response_type=code&redirect_uri=https%3A%2F%2Fwww.aliyundrive.com%2Fsign%2Fcallback&client_id=25dzX3vbYqktVxyX&state=%7B%22origin%22%3A%22file%3A%2F%2F%22%7D HTTP/1.1" 200 None
# 07:04:09.714 aligo.DEBUG SESSIONID bd16c288f31e4a0eb1b73568400b6a00
# 07:04:09.716 aligo.DEBUG Starting new HTTPS connection (1): passport.aliyundrive.com:443
# 07:04:11.024 aligo.DEBUG https://passport.aliyundrive.com:443 "GET /newlogin/qrcode/generate.do?appName=aliyun_drive HTTP/1.1" 200 291
# 07:04:11.028 aligo.INFO GET https://passport.aliyundrive.com/newlogin/qrcode/generate.do?appName=aliyun_drive 200 291
# 07:04:11.028 aligo.INFO 等待扫描二维码，扫码结束后关闭二维码窗口
# 07:04:11.305 aligo.DEBUG https://passport.aliyundrive.com:443 "POST /newlogin/qrcode/query.do?appName=aliyun_drive HTTP/1.1" 200 103
# 07:04:14.526 aligo.DEBUG https://passport.aliyundrive.com:443 "POST /newlogin/qrcode/query.do?appName=aliyun_drive HTTP/1.1" 200 103
# 07:04:17.749 aligo.DEBUG https://passport.aliyundrive.com:443 "POST /newlogin/qrcode/query.do?appName=aliyun_drive HTTP/1.1" 200 103
# 07:04:20.980 aligo.DEBUG https://passport.aliyundrive.com:443 "POST /newlogin/qrcode/query.do?appName=aliyun_drive HTTP/1.1" 200 103
# 07:04:24.326 aligo.DEBUG https://passport.aliyundrive.com:443 "POST /newlogin/qrcode/query.do?appName=aliyun_drive HTTP/1.1" 200 None
# 07:04:24.337 aligo.INFO 已确认
# 07:04:24.338 aligo.INFO 刷新 token
# 07:04:24.340 aligo.DEBUG Starting new HTTPS connection (1): api.aliyundrive.com:443
# 07:04:26.061 aligo.DEBUG https://api.aliyundrive.com:443 "POST /v2/account/token HTTP/1.1" 200 None
# 07:04:26.062 aligo.INFO POST https://api.aliyundrive.com/v2/account/token 200 1927
# 07:04:26.063 aligo.INFO 刷新 token 成功
# 07:04:26.064 aligo.INFO 初始化 x_device_id
# 07:04:26.065 aligo.INFO 保存配置文件 /root/.aligo/aligo.json

# %%
user = ali.get_user()  # 获取用户信息
print(user.user_name, user.nick_name, user.phone)  # 打印用户信息

file_list = ali.get_file_list()  # 获取网盘根目录文件列表
for file in file_list:  # 遍历文件列表
    # 注意：print(file) 默认只显示部分信息，但是实际上file有很多的属性
    print(file.file_id, file.name, file.type)  # 打印文件信息
# Out:
# 07:04:37.208 aligo.DEBUG https://api.aliyundrive.com:443 "POST /v2/user/get HTTP/1.1" 200 None
# 07:04:37.209 aligo.INFO POST https://api.aliyundrive.com/v2/user/get 200 592
# 188***373  18819253373
# 07:04:37.645 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v3/file/list?jsonmask=next_marker%2Citems%28name%2Cfile_id%2Cdrive_id%2Ctype%2Csize%2Ccreated_at%2Cupdated_at%2Ccategory%2Cfile_extension%2Cparent_file_id%2Cmime_type%2Cstarred%2Cthumbnail%2Curl%2Cstreams_info%2Ccontent_hash%2Cuser_tags%2Cuser_meta%2Ctrashed%2Cvideo_media_metadata%2Cvideo_preview_metadata%2Csync_meta%2Csync_device_flag%2Csync_flag%2Cpunish_flag HTTP/1.1" 200 None
# 07:04:37.647 aligo.INFO POST https://api.aliyundrive.com/adrive/v3/file/list?jsonmask=next_marker%2Citems%28name%2Cfile_id%2Cdrive_id%2Ctype%2Csize%2Ccreated_at%2Cupdated_at%2Ccategory%2Cfile_extension%2Cparent_file_id%2Cmime_type%2Cstarred%2Cthumbnail%2Curl%2Cstreams_info%2Ccontent_hash%2Cuser_tags%2Cuser_meta%2Ctrashed%2Cvideo_media_metadata%2Cvideo_preview_metadata%2Csync_meta%2Csync_device_flag%2Csync_flag%2Cpunish_flag 200 63887
# 6978fa8c1e47ae33fbad413c96b126b254d345c5 gpt-oss-20b folder
# 67eab95b48acd92d4f11469bbc49ed49a9418136 merged_v4-4bit folder
# 67eab47ffcaad074d9104b1c805904a208d26332 merged_v4 folder
# 67e82f6a6409bcd6b914460fab86c509e156aeef DeepScalerR-14B-lightr1-360-dpo2400-60step-40step-4bit folder
# 67e28e4384353a82ff65417ab6f49906f6fe476b DeepScalerR-14B-10k-lightr1-360-dpo2400-60step-4bit folder
# 67e1846823fed7b6785347a6a7a78f89ac8fc224 global_step_60 folder
# 67e03ecf7808905095dd45858469d3ca8f41e53e global_step_40 folder
# 67dafa2e91772e102af54e5ebc347057e14c8fe0 7b_dpo_sft_286_continue-7400-grpo16k-60-4bit folder
# 67d9a048bc627635f53f450b9adf5c8fd23202f5 7b_dpo_sft_286_continue-7400-grpo16k-45-4bit folder
# 67d6f838406c346b1a6949eebddac5404af01083 7b_dpo_sft_286_continue-7400-4bit folder
# 67d29e253f739b410f4849a9869120bdd23a4071 temp folder
# 67cc2233e26a0e770c9a413fa744fab586307148 Qwen2.5-14B-Instruct folder
# 67c87daca55f349c027f487f87bef19ae716ace0 DeepSeek-R1-Distill-Qwen-7B-quantized.w4a16 folder
# 67bb2ea0a2e6edd0cae64a32b62d4bec03a956ba r1-math-default folder
# 67ba91264b171a1f4b884eeea54f039103c8f56b DeepSeek-R1-Distill-Qwen-14B-quantized.w4a16 folder
# 67ba053ece20e0ccd68b450c9c115d4f2017afad DeepSeek-R1-Distill-Qwen-14B folder
# 67b6bd8a4aa61a6c4d1842758339df18975af7f0 deepscaler_7b_awq folder
# 67b5f011b18fbf253c6f4d5abd8c8ec68ebdf342 deepscaler-7b folder
# 67b358ae7b470ada84324f62915e36df70ccf717 DeepSeek-R1-Distill-Qwen-32B folder
# 67af94085e4439c7be674372b19e8d6601ddb5fc DeepSeek-R1-Distill-Qwen-7B folder
# 6710d42bac303d65c3b547e39d9a2aba477015c5 regression_paper folder
# 670e99205994457b604547039a0664e7dc54882b dinov2-base_pth folder
# 670e82b030ac3fd841414811b0974e221f138934 dinov2-base folder
# 670d5c7e0fef32bdd6d24141aec510783194dedc dataset folder
# 66599021585f793924174cc7993dedbc2cf2387d deepseek_math_rl_math_concat_lora folder
# 66477fa9613fa96029504ac392425b54e148db9c xlnet-base-finetuned-100-LB-codeNotNeg1-512tokens-2e5-bs16 folder
# 66477ab0d88f7dc793b440f99d5d83dbe9abc832 xlnet-base-finetuned-100-LB-resultNotNeg1-512tokens-2e5-bs16 folder
# 66466048605ba6ba6ed546019daca1be8474ffe8 xlnet-base-finetuned-75-LB-resultNotNeg1-1200words folder
# 6646603f6905354cbf2145e6ac50d5abda2504dd xlnet-base-finetuned-100-LB-codeNotNeg1-1200words folder
# 663f825532d7d27684a84b1181d45926f461811e base-small-en-v1.5 folder
# 663f82489ae6a5f503ae431a9de5537b9bdcc72d bge-base-en-v1.5 folder
# 663f8102c875c0ffc01c458dae572242b0234069 bge-zh-base-1.5 folder
# 663cfcecd73403c98ad640f18c1c3168da35727e xlnet-large-cased folder
# 66207ef0d48542b40ea849faa95f85c6db531243 deepseekmath-rl-mathv3_aimev2-sft folder
# 661fa67f0fa2e2b959fc4560a2e5a1bf3b91a562 deepseekmath-rl-mathv3-sft folder
# 661f2b6758a8cf0d475d4198a7f138cc8bf93eaf deepseekmath-rl-mathv2-sft folder
# 661df7bd4c0987e923424f5d889bb15331125745 deepseekmath-rl-AIME_MATHsft folder
# 661d730f8327b925e8bf46cab5c20086aa85e869 git folder
# 661904e37af9142bd0674eeebd460a58fc09d164 roberta-base-finetuned folder
# 6618c0890c85d67c33bd43bbb1c01df94754255a roberta-base folder
# 6618c079cd42571117974ef88a3658c2ef1134cc xlnet-base-cased folder
# 6616cdcfa02880013419454ca6d6a5b79eccf124 DeepseekMath-kaggle folder
# 6614be61daef9ebe9b924d6f81602980123b23b6 MMOS-DeepSeekMath 7B folder
# 661397f4557ae526c31c4cbc85c9b23662dc68a8 QwenVL_ORPO_alpha0_1_3epoch folder
# 66139199ea8eecff323b4ecd9aec16d0b3138a54 QwenVL_ORPO_alpha0_1_1epoch_TEST_1 folder
# 66137faea173ca69eaa041cfaee9cc59e50a43f3 deepseek-math-7b-rl folder
# 66069a61684efd1cdbce4a21b9cdf4520187f777 QwenVL_SFT_5epoch folder
# 660698d8366d9860957444f48d6746f4816b0339 QwenVL_SFT_2epoch folder
# 6602f93384a0834283974550aeb93974e642a3a9 Qwen15_14B_Chat_try5_step3_sft_norslora_lr1_2e_4_step1000 folder
# 6602bccb39f808aca4714a689cbc0974137fd69f Qwen15_14B_Chat_try5_step3_sft_norslora_lr1_2e_4_step1100 folder
# 660291bd749ee4cc2b7147f3a87abcc2c2970a82 data folder
# 660240f2794c8742851f4ef683a3c460ad6ad0b7 Qwen15_14B_Chat_try5_step1_general_sft_iter4000 folder
# 66012a697a31db1be7d3460fb8addc6899115a97 Qwen15_14B_Chat_try4_ftstep2_sft folder
# 65fc5a3baf66f17dce994752953bf968cc1938aa Qwen15_14B_Chat_sft_50ad_20repeat_iter1200 folder
# 65fbfa267ac4d8cefd1d47cab9396986158955d6 Qwen15_14B_Chat_sft_50ad_20repeat_iter1800 folder
# 65fb0983c612e9d3df294abdbf798e88251e8316 Qwen15_14B_Chat_sft_50ad_10repeat_iter930 folder
# 65f19b6f8ba47fd11ba343db80c51f184f5f8cb4 Qwen1.5-14B-Chat folder
# 65e5dd720855dff2fca44ab5ac5991e92ec223ac internlm-xcomposer2-vl-7b folder
# 65e547f47e75e6d3db07439c9dd6d5a2149e6a43 internlm-xcomposer2-vl-7b-4bit folder
# 6579aaae4e571290845d4c0ea2aee7e7d9ea622e bge-zh-small-1.5 folder
# 65797171b3f2407d9bf0403581dc9c63f05a8147 Qwen-VL-Chat-Int4 folder
# 65797166583974ff9e4847fab0222d4d961b26a6 Qwen-VL-Chat folder
# 67d6fd7ae1737d08317c4449aa5ab4264c985021 flash_attn-2.7.4.post1+cu12torch2.5cxx11abiFALSE-cp310-cp310-linux_x86_64.whl file
# 653a1f7622a8433198774933bb156e28bb0a2d80 pytorch_model-00002-of-00010.bin file
# 653a1f15e66706a984504475b018cc61da1a1220 pytorch_model-00003-of-00010.bin file
# 653a1e453651e41541544f8fa4c4d985d76917e4 pytorch_model-00004-of-00010.bin file
# 653a18efff54775aa4934964af3145dac1ef5304 pytorch_model-00006-of-00010.bin file
# 653a18d5a3b9229cc4d1400d9dd19981439d1e34 pytorch_model-00005-of-00010.bin file
# 653a17fbc37f67133c3c4594aecb8758c948289e pytorch_model-00007-of-00010.bin file
# 653a1256c471d3694b3b451994f344203a12e1b6 pytorch_model-00008-of-00010.bin file
# 653a125691d149062bca49578efb4fe57d4d64b1 pytorch_model-00009-of-00010.bin file
# 653a125636096c0585474a60abd4244a81108ab4 pytorch_model-00010-of-00010.bin file
# 653a0fb38670f3374236440eaaf6fcb9dc82bae4 pytorch_model-00001-of-00010.bin file

# %%
#!pip install transformers
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2026.1.4)

# %%
# !huggingface-cli download lmsys/gpt-oss-20b-bf16  --local-dir gpt-oss-20b-bf16
# Out:
# ⚠️  Warning: 'huggingface-cli download' is deprecated. Use 'hf download' instead.
# Fetching 14 files:   0% 0/14 [00:00<?, ?it/s]Downloading 'config.json' to 'gpt-oss-20b-bf16/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.c51f55087fd512e6a8e44c042adca51a191760aa.incomplete'
# Downloading 'model-00002-of-00005.safetensors' to 'gpt-oss-20b-bf16/.cache/huggingface/download/ewHVStNi_qTCwOvZyUK4XvcG7h0=.c684a411dc1351222bc3bc959abfe767583e4abd43bf1e2a1fca3501382c001a.incomplete'
#
# config.json: 1.59kB [00:00, 6.77MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/config.json
# Downloading 'generation_config.json' to 'gpt-oss-20b-bf16/.cache/huggingface/download/3EVKVggOldJcKSsGjSdoUCN1AyQ=.0574766025e2bc059113d7e5738315caf3737d09.incomplete'
# Downloading 'chat_template.jinja' to 'gpt-oss-20b-bf16/.cache/huggingface/download/yIUQ6Jg7XpBWXEkozaEkS2ih05g=.dc7bb11927d29f653ba2740f2db2c688fd77592f.incomplete'
# Downloading 'model-00001-of-00005.safetensors' to 'gpt-oss-20b-bf16/.cache/huggingface/download/ucOYR0sM0bukMpWiwV3qkLpQbMA=.56d2201120393eccd4c6cf767f085984e6fbdf0a386d6db86310a8e599a3b4a8.incomplete'
# Downloading 'model-00003-of-00005.safetensors' to 'gpt-oss-20b-bf16/.cache/huggingface/download/W6LiZUqSlTR2RfaiI-PdlBA4Fcg=.83c03db9cadbffc124717d02c00c0693dc51fd493230247c25e7f68242eb8603.incomplete'
#
# generation_config.json: 100% 176/176 [00:00<00:00, 1.82MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/generation_config.json
# Downloading 'README.md' to 'gpt-oss-20b-bf16/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.2890a09b7eeab940ea580dfcb4fd9283c37e47f3.incomplete'
#
# model-00002-of-00005.safetensors:   0% 0.00/4.78G [00:00<?, ?B/s]
#
# model-00001-of-00005.safetensors:   0% 0.00/4.61G [00:00<?, ?B/s]
#
#
# model-00003-of-00005.safetensors:   0% 0.00/4.57G [00:00<?, ?B/s]
#
#
#
# chat_template.jinja: 16.7kB [00:00, 47.9MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/chat_template.jinja
# Downloading 'model-00004-of-00005.safetensors' to 'gpt-oss-20b-bf16/.cache/huggingface/download/fNjCg19rjPb4Qv_8lvghvyvUVYM=.87bea83b1c2cec33759ad07a47f009ad1d20bf527c2d058aa58479e292f7653e.incomplete'
# Downloading '.gitattributes' to 'gpt-oss-20b-bf16/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.52373fe24473b1aa44333d318f578ae6bf04b49b.incomplete'
# Downloading 'model-00005-of-00005.safetensors' to 'gpt-oss-20b-bf16/.cache/huggingface/download/GCeZHAC9fJGsUpPJYkRCM0JipPI=.e10168b4dd4f06a43e3795733f831c837b09f969777f36aa3a735f809b8e16bd.incomplete'
#
#
#
#
# README.md: 1.45kB [00:00, 1.43MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/README.md
#
#
#
#
# model-00004-of-00005.safetensors:   0% 0.00/4.78G [00:00<?, ?B/s]
#
#
#
#
# model-00005-of-00005.safetensors:   0% 0.00/3.97G [00:00<?, ?B/s]Downloading 'model.safetensors.index.json' to 'gpt-oss-20b-bf16/.cache/huggingface/download/yVzAsSxRSINSz-tQbpx-TLpfkLU=.563d912f1dca2ec812d66802ccaf8a17fb27e9f7.incomplete'
#
#
#
#
#
#
# .gitattributes: 1.57kB [00:00, 9.07MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/.gitattributes
# Fetching 14 files:   7% 1/14 [00:00<00:07,  1.82it/s]
#
#
#
#
#
# model.safetensors.index.json: 33.6kB [00:00, 102MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/model.safetensors.index.json
# Downloading 'special_tokens_map.json' to 'gpt-oss-20b-bf16/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.73bd12e55e2004cdfff088f85092b39dba2ccdd0.incomplete'
# Downloading 'tokenizer_config.json' to 'gpt-oss-20b-bf16/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.c021cddb0a9dd35b1bf83a9f145be2d9b3757891.incomplete'
# Downloading 'tokenizer.json' to 'gpt-oss-20b-bf16/.cache/huggingface/download/HgM_lKo9sdSCfRtVg7MMFS7EKqo=.0614fe83cadab421296e664e1f48f4261fa8fef6e03e63bb75c20f38e37d07d3.incomplete'
#
#
#
#
#
#
# tokenizer_config.json: 4.20kB [00:00, 26.3MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/tokenizer_config.json
#
#
#
#
#
#
# special_tokens_map.json: 100% 98.0/98.0 [00:00<00:00, 1.10MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/special_tokens_map.json
#
#
#
#
#
#
# tokenizer.json:   0% 0.00/27.9M [00:00<?, ?B/s]
#
#
#
#
#
# tokenizer.json: 100% 27.9M/27.9M [00:00<00:00, 60.1MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/tokenizer.json
#
#
# model-00001-of-00005.safetensors:   0% 34.2k/4.61G [00:01<59:32:43, 21.5kB/s]
#
#
# model-00003-of-00005.safetensors:   0% 51.5k/4.57G [00:01<40:38:00, 31.2kB/s]
#
# model-00001-of-00005.safetensors:   0% 911k/4.61G [00:03<3:47:21, 338kB/s]
#
#
# model-00003-of-00005.safetensors:   0% 14.8M/4.57G [00:03<14:52, 5.10MB/s]
#
# model-00001-of-00005.safetensors:   0% 17.7M/4.61G [00:04<13:49, 5.54MB/s]
#
#
# model-00003-of-00005.safetensors:   2% 69.9M/4.57G [00:05<05:01, 14.9MB/s]
#
# model-00001-of-00005.safetensors:   2% 84.7M/4.61G [00:09<06:54, 10.9MB/s]
#
#
# model-00003-of-00005.safetensors:   6% 270M/4.57G [00:10<02:08, 33.5MB/s]
#
# model-00001-of-00005.safetensors:   3% 152M/4.61G [00:10<03:41, 20.1MB/s]
#
#
# model-00003-of-00005.safetensors:   9% 404M/4.57G [00:11<01:23, 49.6MB/s]
#
# model-00001-of-00005.safetensors:   9% 420M/4.61G [00:13<01:23, 50.1MB/s]
#
#
# model-00003-of-00005.safetensors:  13% 605M/4.57G [00:13<01:07, 59.1MB/s]
#
# model-00001-of-00005.safetensors:  11% 487M/4.61G [00:19<02:25, 28.4MB/s]
#
#
#
# model-00004-of-00005.safetensors:   1% 67.1M/4.78G [00:19<22:49, 3.44MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:   2% 67.0M/3.97G [00:19<19:14, 3.39MB/s]
#
# model-00001-of-00005.safetensors:  14% 629M/4.61G [00:23<02:10, 30.6MB/s]
#
#
#
# model-00004-of-00005.safetensors:   3% 134M/4.78G [00:23<12:07, 6.39MB/s]
#
#
# model-00003-of-00005.safetensors:  17% 754M/4.57G [00:23<02:10, 29.3MB/s]
# model-00002-of-00005.safetensors:   1% 67.0M/4.78G [00:27<32:45, 2.40MB/s]
#
# model-00001-of-00005.safetensors:  15% 696M/4.61G [00:28<02:38, 24.7MB/s]
#
#
# model-00003-of-00005.safetensors:  19% 888M/4.57G [00:28<02:09, 28.4MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:   3% 134M/3.97G [00:28<12:52, 4.97MB/s]
#
# model-00001-of-00005.safetensors:  19% 897M/4.61G [00:29<01:31, 40.6MB/s]
#
#
# model-00003-of-00005.safetensors:  21% 955M/4.57G [00:29<01:54, 31.5MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:   5% 201M/3.97G [00:29<07:20, 8.57MB/s]
# model-00002-of-00005.safetensors:   1% 69.3M/4.78G [00:30<35:15, 2.23MB/s]
#
#
#
# model-00004-of-00005.safetensors:   4% 201M/4.78G [00:31<10:34, 7.22MB/s]
#
#
# model-00003-of-00005.safetensors:  24% 1.09G/4.57G [00:31<01:29, 39.1MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:   5% 214M/3.97G [00:31<07:35, 8.26MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:   7% 281M/3.97G [00:33<04:36, 13.4MB/s]
# model-00002-of-00005.safetensors:   1% 70.0M/4.78G [00:33<41:50, 1.88MB/s]
#
# model-00001-of-00005.safetensors:  22% 1.03G/4.61G [00:33<01:36, 37.1MB/s]
#
#
#
# model-00004-of-00005.safetensors:   7% 335M/4.78G [00:34<05:15, 14.1MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  10% 415M/3.97G [00:34<02:21, 25.1MB/s]
# model-00002-of-00005.safetensors:   3% 137M/4.78G [00:35<12:13, 6.33MB/s]
#
#
# model-00003-of-00005.safetensors:  27% 1.22G/4.57G [00:37<01:47, 31.3MB/s]
#
#
#
# model-00004-of-00005.safetensors:   8% 403M/4.78G [00:37<04:47, 15.2MB/s]
# model-00002-of-00005.safetensors:   4% 204M/4.78G [00:38<07:48, 9.76MB/s]
#
# model-00001-of-00005.safetensors:  26% 1.21G/4.61G [00:38<01:30, 37.7MB/s]
#
#
#
# model-00004-of-00005.safetensors:  10% 470M/4.78G [00:38<03:38, 19.7MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  12% 483M/3.97G [00:38<02:34, 22.5MB/s]
#
# model-00001-of-00005.safetensors:  28% 1.29G/4.61G [00:39<01:16, 43.6MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  14% 537M/3.97G [00:40<02:15, 25.3MB/s]
# model-00002-of-00005.safetensors:   5% 248M/4.78G [00:40<06:16, 12.1MB/s]
#
# model-00001-of-00005.safetensors:  30% 1.36G/4.61G [00:40<01:11, 45.1MB/s]
#
#
#
# model-00004-of-00005.safetensors:  11% 537M/4.78G [00:43<04:08, 17.1MB/s]
# model-00002-of-00005.safetensors:   7% 315M/4.78G [00:44<05:35, 13.3MB/s]
#
# model-00001-of-00005.safetensors:  33% 1.51G/4.61G [00:44<01:16, 40.3MB/s]
#
#
# model-00003-of-00005.safetensors:  28% 1.29G/4.57G [00:45<02:32, 21.6MB/s]
#
# model-00001-of-00005.safetensors:  33% 1.52G/4.61G [00:47<01:45, 29.3MB/s]
# model-00002-of-00005.safetensors:  11% 516M/4.78G [00:48<02:44, 26.0MB/s]
#
#
#
# model-00004-of-00005.safetensors:  13% 607M/4.78G [00:48<04:16, 16.3MB/s]
#
#
# model-00003-of-00005.safetensors:  30% 1.36G/4.57G [00:54<03:30, 15.3MB/s]
# model-00002-of-00005.safetensors:  12% 583M/4.78G [00:54<03:39, 19.1MB/s]
#
#
#
# model-00004-of-00005.safetensors:  15% 741M/4.78G [00:54<03:42, 18.1MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  17% 671M/3.97G [00:55<04:03, 13.6MB/s]
#
# model-00001-of-00005.safetensors:  33% 1.52G/4.61G [00:59<01:45, 29.3MB/s]
#
#
#
# model-00004-of-00005.safetensors:  18% 874M/4.78G [01:02<03:35, 18.2MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  20% 805M/3.97G [01:02<03:31, 15.0MB/s]
#
#
# model-00003-of-00005.safetensors:  31% 1.42G/4.57G [01:03<04:14, 12.4MB/s]
#
# model-00001-of-00005.safetensors:  35% 1.59G/4.61G [01:03<04:07, 12.2MB/s]
# model-00002-of-00005.safetensors:  13% 604M/4.78G [01:03<06:02, 11.5MB/s]
#
#
#
# model-00004-of-00005.safetensors:  20% 941M/4.78G [01:03<03:01, 21.2MB/s]
#
# model-00001-of-00005.safetensors:  35% 1.63G/4.61G [01:04<03:41, 13.5MB/s]
# model-00002-of-00005.safetensors:  14% 671M/4.78G [01:04<04:28, 15.3MB/s]
#
#
#
# model-00004-of-00005.safetensors:  21% 1.01G/4.78G [01:04<02:28, 25.4MB/s]
#
#
# model-00003-of-00005.safetensors:  36% 1.63G/4.57G [01:05<02:13, 22.0MB/s]
#
#
#
# model-00004-of-00005.safetensors:  22% 1.07G/4.78G [01:05<02:02, 30.3MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  22% 873M/3.97G [01:05<03:12, 16.1MB/s]
#
# model-00001-of-00005.safetensors:  37% 1.69G/4.61G [01:06<02:53, 16.8MB/s]
# model-00002-of-00005.safetensors:  15% 738M/4.78G [01:06<03:36, 18.7MB/s]
#
#
# model-00003-of-00005.safetensors:  41% 1.89G/4.57G [01:06<01:10, 37.8MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  24% 940M/3.97G [01:06<02:33, 19.8MB/s]
# model-00002-of-00005.safetensors:  17% 805M/4.78G [01:06<02:40, 24.7MB/s]
#
#
# model-00003-of-00005.safetensors:  43% 1.95G/4.57G [01:07<01:04, 40.5MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  25% 1.01G/3.97G [01:08<02:06, 23.5MB/s]
# model-00002-of-00005.safetensors:  18% 874M/4.78G [01:08<02:13, 29.2MB/s]
#
# model-00001-of-00005.safetensors:  38% 1.76G/4.61G [01:08<02:31, 18.9MB/s]
#
#
#
# model-00004-of-00005.safetensors:  24% 1.14G/4.78G [01:09<02:21, 25.7MB/s]
#
# model-00001-of-00005.safetensors:  40% 1.83G/4.61G [01:10<02:01, 22.8MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  27% 1.07G/3.97G [01:10<01:54, 25.2MB/s]
# model-00002-of-00005.safetensors:  20% 941M/4.78G [01:10<02:10, 29.5MB/s]
#
#
# model-00003-of-00005.safetensors:  47% 2.15G/4.57G [01:12<00:59, 40.9MB/s]
#
# model-00001-of-00005.safetensors:  42% 1.94G/4.61G [01:12<01:28, 30.3MB/s]
# model-00002-of-00005.safetensors:  22% 1.08G/4.78G [01:12<01:39, 37.4MB/s]
#
# model-00001-of-00005.safetensors:  43% 1.96G/4.61G [01:16<02:18, 19.2MB/s]
# model-00002-of-00005.safetensors:  25% 1.21G/4.78G [01:17<01:50, 32.3MB/s]
#
#
#
# model-00004-of-00005.safetensors:  27% 1.28G/4.78G [01:17<02:55, 20.0MB/s]
#
# model-00001-of-00005.safetensors:  45% 2.06G/4.61G [01:18<01:43, 24.8MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  29% 1.14G/3.97G [01:23<03:51, 12.3MB/s]
#
#
# model-00003-of-00005.safetensors:  50% 2.28G/4.57G [01:24<01:36, 23.8MB/s]
#
# model-00001-of-00005.safetensors:  46% 2.11G/4.61G [01:29<03:09, 13.2MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  32% 1.26G/3.97G [01:28<03:03, 14.8MB/s]
# model-00002-of-00005.safetensors:  27% 1.28G/4.78G [01:29<03:34, 16.3MB/s]
#
#
#
# model-00004-of-00005.safetensors:  29% 1.41G/4.78G [01:29<03:35, 15.6MB/s]
#
#
# model-00003-of-00005.safetensors:  50% 2.30G/4.57G [01:29<02:04, 18.2MB/s]
#
# model-00001-of-00005.safetensors:  47% 2.16G/4.61G [01:30<02:30, 16.2MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  33% 1.33G/3.97G [01:30<02:28, 17.9MB/s]
# model-00002-of-00005.safetensors:  30% 1.41G/4.78G [01:30<02:20, 24.0MB/s]
#
#
# model-00003-of-00005.safetensors:  55% 2.51G/4.57G [01:31<01:09, 29.6MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  35% 1.40G/3.97G [01:31<01:59, 21.6MB/s]
# model-00002-of-00005.safetensors:  31% 1.48G/4.78G [01:31<02:00, 27.4MB/s]
# model-00002-of-00005.safetensors:  32% 1.54G/4.78G [01:33<01:47, 30.1MB/s]
#
#
#
# model-00004-of-00005.safetensors:  31% 1.48G/4.78G [01:33<03:30, 15.7MB/s]
#
#
# model-00003-of-00005.safetensors:  58% 2.64G/4.57G [01:34<00:58, 33.3MB/s]
#
#
#
# model-00004-of-00005.safetensors:  35% 1.68G/4.78G [01:34<01:48, 28.6MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  39% 1.53G/3.97G [01:34<01:29, 27.4MB/s]
#
#
#
# model-00004-of-00005.safetensors:  37% 1.75G/4.78G [01:43<02:40, 18.9MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  40% 1.60G/3.97G [01:43<02:17, 17.3MB/s]
# model-00002-of-00005.safetensors:  34% 1.61G/4.78G [01:47<04:02, 13.1MB/s]
#
#
# model-00003-of-00005.safetensors:  61% 2.77G/4.57G [01:49<01:39, 18.0MB/s]
#
# model-00001-of-00005.safetensors:  48% 2.23G/4.61G [01:49<05:19, 7.44MB/s]
#
#
#
# model-00004-of-00005.safetensors:  41% 1.95G/4.78G [01:50<02:05, 22.5MB/s]
# model-00002-of-00005.safetensors:  35% 1.68G/4.78G [01:51<03:51, 13.4MB/s]
#
#
#
# model-00004-of-00005.safetensors:  44% 2.08G/4.78G [01:52<01:36, 27.9MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  42% 1.67G/3.97G [01:52<02:58, 12.9MB/s]
# model-00002-of-00005.safetensors:  37% 1.75G/4.78G [01:52<02:57, 17.1MB/s]
#
# model-00001-of-00005.safetensors:  49% 2.26G/4.61G [01:52<04:58, 7.86MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  42% 1.68G/3.97G [01:53<02:54, 13.2MB/s]
#
#
# model-00003-of-00005.safetensors:  62% 2.84G/4.57G [01:54<01:39, 17.3MB/s]
#
# model-00001-of-00005.safetensors:  52% 2.40G/4.61G [01:54<02:29, 14.8MB/s]
#
#
#
# model-00004-of-00005.safetensors:  45% 2.15G/4.78G [01:54<01:34, 27.8MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  44% 1.75G/3.97G [01:54<02:11, 16.9MB/s]
#
#
# model-00003-of-00005.safetensors:  65% 2.97G/4.57G [01:56<01:08, 23.2MB/s]
#
#
#
# model-00004-of-00005.safetensors:  46% 2.21G/4.78G [01:59<01:52, 22.7MB/s]
# model-00002-of-00005.safetensors:  39% 1.88G/4.78G [02:00<02:48, 17.3MB/s]
#
#
# model-00003-of-00005.safetensors:  70% 3.18G/4.57G [02:04<00:58, 23.7MB/s]
#
# model-00001-of-00005.safetensors:  53% 2.47G/4.61G [02:04<03:11, 11.2MB/s]
#
#
#
# model-00004-of-00005.safetensors:  49% 2.35G/4.78G [02:04<01:39, 24.5MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  47% 1.88G/3.97G [02:04<02:17, 15.2MB/s]
#
#
# model-00003-of-00005.safetensors:  71% 3.24G/4.57G [02:07<00:58, 22.5MB/s]
#
#
#
# model-00004-of-00005.safetensors:  50% 2.41G/4.78G [02:15<02:38, 15.0MB/s]
# model-00002-of-00005.safetensors:  41% 1.95G/4.78G [02:15<04:37, 10.2MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  49% 1.95G/3.97G [02:16<03:06, 10.8MB/s]
#
#
#
# model-00004-of-00005.safetensors:  52% 2.48G/4.78G [02:16<02:08, 17.9MB/s]
#
# model-00001-of-00005.safetensors:  53% 2.47G/4.61G [02:19<03:11, 11.2MB/s]
#
#
# model-00003-of-00005.safetensors:  72% 3.31G/4.57G [02:19<00:55, 22.5MB/s]
# model-00002-of-00005.safetensors:  44% 2.08G/4.78G [02:22<03:31, 12.8MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  51% 2.02G/3.97G [02:22<03:00, 10.9MB/s]
#
#
# model-00003-of-00005.safetensors:  74% 3.38G/4.57G [02:22<01:17, 15.3MB/s]
#
# model-00001-of-00005.safetensors:  55% 2.53G/4.61G [02:22<04:54, 7.07MB/s]
#
#
#
# model-00004-of-00005.safetensors:  53% 2.55G/4.78G [02:23<02:27, 15.1MB/s]
# model-00002-of-00005.safetensors:  45% 2.15G/4.78G [02:26<03:16, 13.4MB/s]
#
# model-00001-of-00005.safetensors:  58% 2.67G/4.61G [02:26<02:58, 10.9MB/s]
# model-00002-of-00005.safetensors:  46% 2.21G/4.78G [02:27<02:31, 16.9MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  52% 2.07G/3.97G [02:27<02:59, 10.6MB/s]
#
#
# model-00003-of-00005.safetensors:  75% 3.44G/4.57G [02:27<01:15, 14.9MB/s]
#
#
#
# model-00004-of-00005.safetensors:  55% 2.62G/4.78G [02:28<02:26, 14.8MB/s]
# model-00002-of-00005.safetensors:  48% 2.28G/4.78G [02:28<02:02, 20.4MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  55% 2.20G/3.97G [02:28<01:40, 17.8MB/s]
#
#
# model-00003-of-00005.safetensors:  77% 3.51G/4.57G [02:28<01:00, 17.6MB/s]
#
# model-00001-of-00005.safetensors:  61% 2.80G/4.61G [02:29<01:54, 15.8MB/s]
# model-00002-of-00005.safetensors:  49% 2.35G/4.78G [02:32<02:07, 19.0MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  57% 2.26G/3.97G [02:32<01:36, 17.7MB/s]
#
#
# model-00003-of-00005.safetensors:  78% 3.58G/4.57G [02:32<00:56, 17.4MB/s]
#
#
#
# model-00004-of-00005.safetensors:  56% 2.68G/4.78G [02:33<02:27, 14.2MB/s]
# model-00002-of-00005.safetensors:  52% 2.48G/4.78G [02:33<01:16, 29.9MB/s]
#
# model-00001-of-00005.safetensors:  62% 2.87G/4.61G [02:34<01:55, 15.1MB/s]
# model-00002-of-00005.safetensors:  55% 2.62G/4.78G [02:35<00:56, 38.5MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  60% 2.37G/3.97G [02:35<01:15, 21.1MB/s]
#
#
# model-00003-of-00005.safetensors:  81% 3.70G/4.57G [02:36<00:41, 21.2MB/s]
#
# model-00001-of-00005.safetensors:  65% 3.00G/4.61G [02:36<01:15, 21.3MB/s]
#
#
#
# model-00004-of-00005.safetensors:  59% 2.82G/4.78G [02:36<01:40, 19.5MB/s]
# model-00002-of-00005.safetensors:  56% 2.68G/4.78G [02:37<00:55, 37.7MB/s]
#
#
# model-00003-of-00005.safetensors:  82% 3.76G/4.57G [02:38<00:34, 23.1MB/s]
#
# model-00001-of-00005.safetensors:  67% 3.07G/4.61G [02:38<01:07, 22.9MB/s]
#
#
#
# model-00004-of-00005.safetensors:  60% 2.88G/4.78G [02:38<01:27, 21.8MB/s]
# model-00002-of-00005.safetensors:  58% 2.75G/4.78G [02:39<00:55, 36.3MB/s]
#
#
# model-00003-of-00005.safetensors:  84% 3.83G/4.57G [02:39<00:27, 26.4MB/s]
#
# model-00001-of-00005.safetensors:  68% 3.14G/4.61G [02:40<01:00, 24.5MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  61% 2.44G/3.97G [02:40<01:22, 18.6MB/s]
#
#
#
# model-00004-of-00005.safetensors:  63% 3.02G/4.78G [02:41<01:02, 28.5MB/s]
# model-00002-of-00005.safetensors:  59% 2.82G/4.78G [02:41<00:55, 35.4MB/s]
#
#
# model-00003-of-00005.safetensors:  85% 3.90G/4.57G [02:42<00:25, 26.4MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  62% 2.48G/3.97G [02:42<01:14, 20.0MB/s]
#
#
# model-00003-of-00005.safetensors:  87% 3.97G/4.57G [02:43<00:18, 33.3MB/s]
#
#
#
# model-00004-of-00005.safetensors:  65% 3.08G/4.78G [02:42<00:55, 30.9MB/s]
#
# model-00001-of-00005.safetensors:  69% 3.20G/4.61G [02:43<00:55, 25.2MB/s]
# model-00002-of-00005.safetensors:  60% 2.89G/4.78G [02:46<01:18, 24.1MB/s]
#
#
#
# model-00004-of-00005.safetensors:  69% 3.29G/4.78G [02:46<00:38, 38.4MB/s]
#
# model-00001-of-00005.safetensors:  71% 3.27G/4.61G [02:47<01:00, 22.1MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  64% 2.55G/3.97G [02:47<01:23, 17.1MB/s]
#
# model-00001-of-00005.safetensors:  74% 3.40G/4.61G [02:48<00:35, 33.9MB/s]
#
#
# model-00003-of-00005.safetensors:  88% 4.03G/4.57G [02:48<00:24, 22.0MB/s]
# model-00002-of-00005.safetensors:  62% 2.95G/4.78G [02:52<01:40, 18.2MB/s]
#
#
#
# model-00004-of-00005.safetensors:  70% 3.35G/4.78G [02:52<00:54, 26.1MB/s]
#
# model-00001-of-00005.safetensors:  77% 3.54G/4.61G [02:53<00:34, 31.1MB/s]
#
#
# model-00003-of-00005.safetensors:  90% 4.10G/4.57G [02:53<00:24, 18.8MB/s]
#
#
# model-00003-of-00005.safetensors:  91% 4.17G/4.57G [02:54<00:16, 24.9MB/s]
#
#
#
# model-00004-of-00005.safetensors:  72% 3.42G/4.78G [02:54<00:45, 29.7MB/s]
#
#
# model-00003-of-00005.safetensors:  93% 4.23G/4.57G [02:54<00:10, 33.4MB/s]
#
# model-00001-of-00005.safetensors:  80% 3.67G/4.61G [02:59<00:33, 27.7MB/s]
#
#
# model-00003-of-00005.safetensors:  94% 4.30G/4.57G [02:59<00:11, 22.7MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  68% 2.68G/3.97G [02:59<01:33, 13.8MB/s]
#
#
#
# model-00004-of-00005.safetensors:  73% 3.49G/4.78G [03:03<01:14, 17.4MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  71% 2.82G/3.97G [03:08<01:22, 14.0MB/s]
#
#
#
# model-00004-of-00005.safetensors:  74% 3.55G/4.78G [03:09<01:21, 15.1MB/s]
# model-00002-of-00005.safetensors:  62% 2.95G/4.78G [03:09<01:40, 18.2MB/s]
#
# model-00001-of-00005.safetensors:  81% 3.74G/4.61G [03:09<00:31, 27.7MB/s]
#
#
# model-00003-of-00005.safetensors:  94% 4.30G/4.57G [03:09<00:11, 22.7MB/s]
#
# model-00001-of-00005.safetensors:  83% 3.81G/4.61G [03:15<00:52, 15.4MB/s]
# model-00002-of-00005.safetensors:  63% 3.02G/4.78G [03:15<03:58, 7.38MB/s]
#
#
# model-00003-of-00005.safetensors:  96% 4.37G/4.57G [03:19<00:23, 8.40MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  71% 2.82G/3.97G [03:19<01:22, 14.0MB/s]
#
#
#
# model-00004-of-00005.safetensors:  74% 3.55G/4.78G [03:19<01:21, 15.1MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  73% 2.89G/3.97G [03:19<01:39, 11.0MB/s]
# model-00002-of-00005.safetensors:  66% 3.15G/4.78G [03:20<02:24, 11.2MB/s]
#
#
#
# model-00004-of-00005.safetensors:  75% 3.57G/4.78G [03:20<02:14, 8.97MB/s]
#
#
# model-00003-of-00005.safetensors:  97% 4.44G/4.57G [03:23<00:13, 9.92MB/s]
# model-00002-of-00005.safetensors:  69% 3.29G/4.78G [03:26<01:47, 13.9MB/s]
#
#
# model-00003-of-00005.safetensors:  99% 4.50G/4.57G [03:26<00:05, 12.2MB/s]
#
# model-00001-of-00005.safetensors:  85% 3.94G/4.61G [03:29<00:43, 15.4MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  76% 3.02G/3.97G [03:29<01:20, 11.8MB/s]
# model-00002-of-00005.safetensors:  70% 3.35G/4.78G [03:29<01:38, 14.5MB/s]
#
#
#
# model-00004-of-00005.safetensors:  76% 3.64G/4.78G [03:30<02:20, 8.11MB/s]
# model-00002-of-00005.safetensors:  72% 3.42G/4.78G [03:30<01:15, 18.1MB/s]
#
# model-00001-of-00005.safetensors:  87% 4.01G/4.61G [03:31<00:42, 14.3MB/s]
#
#
# model-00003-of-00005.safetensors: 100% 4.57G/4.57G [03:31<00:00, 21.6MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/model-00003-of-00005.safetensors
#
# model-00002-of-00005.safetensors:  73% 3.51G/4.78G [03:31<00:52, 24.1MB/s]
#
# model-00001-of-00005.safetensors:  88% 4.08G/4.61G [03:36<00:38, 14.1MB/s]
# model-00002-of-00005.safetensors:  75% 3.57G/4.78G [03:36<01:00, 19.9MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  78% 3.09G/3.97G [03:36<01:19, 11.2MB/s]
# model-00002-of-00005.safetensors:  78% 3.71G/4.78G [03:37<00:34, 31.3MB/s]
# model-00002-of-00005.safetensors:  79% 3.78G/4.78G [03:42<00:40, 24.6MB/s]
#
#
#
# model-00004-of-00005.safetensors:  79% 3.78G/4.78G [03:42<01:47, 9.33MB/s]
#
#
#
# model-00004-of-00005.safetensors:  80% 3.84G/4.78G [03:42<01:16, 12.3MB/s]
#
#
#
# model-00004-of-00005.safetensors:  82% 3.91G/4.78G [03:48<01:11, 12.1MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  79% 3.15G/3.97G [03:48<01:28, 9.26MB/s]
#
# model-00001-of-00005.safetensors:  90% 4.14G/4.61G [03:48<00:43, 10.7MB/s]
#
# model-00001-of-00005.safetensors:  91% 4.21G/4.61G [03:49<00:29, 13.4MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  81% 3.22G/3.97G [03:49<01:03, 11.9MB/s]
#
#
#
# model-00004-of-00005.safetensors:  83% 3.98G/4.78G [03:54<01:08, 11.8MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  83% 3.29G/3.97G [03:59<01:09, 9.82MB/s]
# model-00002-of-00005.safetensors:  80% 3.84G/4.78G [03:59<00:38, 24.6MB/s]
#
# model-00001-of-00005.safetensors:  91% 4.21G/4.61G [03:59<00:29, 13.4MB/s]
# model-00002-of-00005.safetensors:  82% 3.91G/4.78G [04:00<01:08, 12.7MB/s]
#
#
#
# model-00004-of-00005.safetensors:  86% 4.11G/4.78G [04:00<00:45, 14.7MB/s]
#
# model-00001-of-00005.safetensors:  93% 4.28G/4.61G [04:01<00:33, 9.96MB/s]
#
#
#
# model-00004-of-00005.safetensors:  87% 4.18G/4.78G [04:01<00:33, 18.2MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  84% 3.33G/3.97G [04:01<01:00, 10.7MB/s]
#
#
#
# model-00004-of-00005.safetensors:  89% 4.25G/4.78G [04:04<00:28, 19.1MB/s]
#
# model-00001-of-00005.safetensors:  94% 4.34G/4.61G [04:04<00:23, 11.5MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  85% 3.40G/3.97G [04:04<00:45, 12.6MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  87% 3.46G/3.97G [04:04<00:28, 17.8MB/s]
# model-00002-of-00005.safetensors:  83% 3.98G/4.78G [04:05<01:01, 13.0MB/s]
#
# model-00001-of-00005.safetensors:  96% 4.41G/4.61G [04:05<00:13, 14.5MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  88% 3.50G/3.97G [04:05<00:23, 20.1MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  90% 3.57G/3.97G [04:06<00:14, 28.5MB/s]
# model-00002-of-00005.safetensors:  85% 4.04G/4.78G [04:07<00:49, 15.0MB/s]
# model-00002-of-00005.safetensors:  86% 4.11G/4.78G [04:09<00:38, 17.6MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  92% 3.64G/3.97G [04:10<00:14, 22.4MB/s]
#
#
#
# model-00004-of-00005.safetensors:  90% 4.31G/4.78G [04:11<00:30, 15.2MB/s]
#
# model-00001-of-00005.safetensors:  97% 4.48G/4.61G [04:11<00:09, 13.5MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  95% 3.77G/3.97G [04:11<00:05, 36.9MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  97% 3.84G/3.97G [04:12<00:02, 45.9MB/s]
#
#
#
# model-00004-of-00005.safetensors:  92% 4.38G/4.78G [04:12<00:20, 19.6MB/s]
# model-00002-of-00005.safetensors:  87% 4.18G/4.78G [04:12<00:33, 18.2MB/s]
#
#
#
# model-00004-of-00005.safetensors:  93% 4.45G/4.78G [04:12<00:13, 25.7MB/s]
#
#
#
# model-00004-of-00005.safetensors:  94% 4.51G/4.78G [04:12<00:07, 34.7MB/s]
# model-00002-of-00005.safetensors:  89% 4.25G/4.78G [04:13<00:22, 23.5MB/s]
# model-00002-of-00005.safetensors:  90% 4.31G/4.78G [04:13<00:14, 31.6MB/s]
# model-00002-of-00005.safetensors:  92% 4.38G/4.78G [04:14<00:09, 42.4MB/s]
# model-00002-of-00005.safetensors:  93% 4.45G/4.78G [04:14<00:06, 54.9MB/s]
# model-00002-of-00005.safetensors:  94% 4.51G/4.78G [04:14<00:03, 75.0MB/s]
#
#
#
# model-00004-of-00005.safetensors:  96% 4.58G/4.78G [04:14<00:05, 34.6MB/s]
#
# model-00001-of-00005.safetensors:  99% 4.54G/4.61G [04:15<00:04, 14.9MB/s]
#
#
#
#
# model-00005-of-00005.safetensors:  98% 3.91G/3.97G [04:15<00:01, 34.4MB/s]
#
#
#
# model-00004-of-00005.safetensors:  97% 4.65G/4.78G [04:15<00:03, 43.7MB/s]
# model-00002-of-00005.safetensors:  96% 4.58G/4.78G [04:16<00:03, 61.5MB/s]
# model-00002-of-00005.safetensors:  97% 4.65G/4.78G [04:16<00:01, 76.1MB/s]
#
# model-00001-of-00005.safetensors: 100% 4.61G/4.61G [04:16<00:00, 18.0MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/model-00001-of-00005.safetensors
# Fetching 14 files:  43% 6/14 [04:16<06:00, 45.01s/it]
#
#
#
#
# model-00005-of-00005.safetensors: 100% 3.97G/3.97G [04:16<00:00, 15.5MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/model-00005-of-00005.safetensors
#
#
#
#
# model-00004-of-00005.safetensors:  99% 4.71G/4.78G [04:16<00:01, 44.6MB/s]
# model-00002-of-00005.safetensors: 100% 4.78G/4.78G [04:21<00:00, 18.3MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/model-00002-of-00005.safetensors
# Fetching 14 files:  50% 7/14 [04:21<04:18, 36.94s/it]
#
#
#
# model-00004-of-00005.safetensors: 100% 4.78G/4.78G [04:21<00:00, 18.3MB/s]
# Download complete. Moving file to gpt-oss-20b-bf16/model-00004-of-00005.safetensors
# Fetching 14 files: 100% 14/14 [04:21<00:00, 18.69s/it]
# /content/gpt-oss-20b-bf16

# %%
ali.upload_folder('gpt-oss-20b-bf16')
# Out:
# 07:16:40.038 aligo.DEBUG Resetting dropped connection: api.aliyundrive.com
# 07:16:40.805 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:16:40.806 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 269
# 07:16:40.808 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/special_tokens_map.json
# 07:16:41.151 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:16:41.152 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 468
# 07:16:41.153 aligo.INFO 文件秒传成功 /content/gpt-oss-20b-bf16/special_tokens_map.json
# 07:16:41.154 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/model.safetensors.index.json
# 07:16:41.449 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:16:41.450 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 2977
#   0%|          | 0.00/33.6k [00:00<?, ?B/s]07:16:41.460 aligo.DEBUG Starting new HTTPS connection (1): cn-beijing-data.aliyundrive.net:443
# 07:16:43.456 aligo.DEBUG https://cn-beijing-data.aliyundrive.net:443 "PUT /v5b2We5n%2F580097623%2F697b095921b938b6f6054456a1f7870509e7cdce%2F697b095970c1b24f1fb648d696a0938fe45a5094?ap=pJZInNHN2dZWk8qg&di=bj29&dr=580097623&f=697b095921b938b6f6054456a1f7870509e7cdce&op=u&partNumber=1&pds-params=%7B%22ap%22%3A%22pJZInNHN2dZWk8qg%22%7D&security-token=CAISvgJ1q6Ft5B2yfSjIr5nSHfDRi7Jl2beYenzpnloNSrpWvK3qrDz2IHhMf3NpBOkZvvQ1lGlU6%2Fcalq5rR4QAXlDfNVuJXQD%2FqlHPWZHInuDox55m4cTXNAr%2BIhr%2F29CoEIedZdjBe%2FCrRknZnytou9XTfimjWFrXWv%2Fgy%2BQQDLItUxK%2FcCBNCfpPOwJms7V6D3bKMuu3OROY6Qi5TmgQ41Uh1jgjtPzkkpfFtkGF1GeXkLFF%2B97DRbG%2FdNRpMZtFVNO44fd7bKKp0lQLs0ARrv4r1fMUqW2X543AUgFLhy2KKMPY99xpFgh9a7j0iCbSGyUu%2FhcRm5sw9%2Byfo34lVYnew71A51bLbuHwufJ7FxfIREfquk63pvSlHLcLPe0Kjzzleo2k1XRPVFF%2B535IaHXuToXDnvSi%2Bw8DB%2FXtuMkagAFBbTAS99MZc6OvEYY%2BCM9JN1zHBPxz6qVm
QAXlDfNVuJXQD%2FqlHPWZHInuDox55m4cTXNAr%2BIhr%2F29CoEIedZdjBe%2FCrRknZnytou9XTfimjWFrXWv%2Fgy%2BQQDLItUxK%2FcCBNCfpPOwJms7V6D3bKMuu3OROY6Qi5TmgQ41Uh1jgjtPzkkpfFtkGF1GeXkLFF%2B97DRbG%2FdNRpMZtFVNO44fd7bKKp0lQLs0ARrv4r1fMUqW2X543AUgFLhy2KKMPY99xpFgh9a7j0iCbSGyUu%2FhcRm5sw9%2Byfo34lVYnew71A51bLbuHwufJ7FxfIREfquk63pvSlHLcLPe0Kjzzleo2k1XRPVFF%2B535IaHXuToXDnvSi%2Bw8DB%2FXtuMkagAFBbTAS99MZc6OvEYY%2BCM9JN1zHBPxz6qVmBRrmeCfSVOr7HrQSqkCOTe%2FHnHnDjH8%2Fy7CU9r1Upbw14nQMwYhfMv3DFw0w4OkLsuZB629dkKMdlq1Ffaq0QRL0YJ%2Bgh1uepnFYOypnrkxOKq%2B1752kbM6HLzmby%2F8PqMzByvanbiAA&u=e3e170d528284a56b5dce1b3fcd5f072&uploadId=D7339FB9A202454DAAD33C46CE6EE6D4&x-oss-access-key-id=STS.NZgVJefmDnusxZXzZXF5zShAN&x-oss-expires=1769674611&x-oss-signature=KjwlOdmpiCa6y2zSrZaqokNkbXkf0MpGUqwxBFE8EYA%3D&x-oss-signature-version=OSS2 HTTP/1.1" 200 0
# 100%|██████████| 125/125 [00:00<00:00, 421B/s]
# 07:16:52.034 aligo.DEBUG https://api.aliyundrive.com:443 "POST /v2/file/complete HTTP/1.1" 200 None
# 07:16:52.035 aligo.INFO POST https://api.aliyundrive.com/v2/file/complete 200 1287
# 07:16:52.037 aligo.INFO 文件上传完成 /content/gpt-oss-20b-bf16/.cache/huggingface/download/model-00004-of-00005.safetensors.metadata
# 07:16:52.039 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/.cache/huggingface/download/model.safetensors.index.json.lock
# 07:16:52.319 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:16:52.320 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 478
# 07:16:52.321 aligo.INFO 文件秒传成功 /content/gpt-oss-20b-bf16/.cache/huggingface/download/model.safetensors.index.json.lock
# 07:16:52.322 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/.cache/huggingface/download/tokenizer.json.lock
# 07:16:52.605 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:16:52.606 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 464
# 07:16:52.607 aligo.INFO 文件秒传成功 /content/gpt-oss-20b-bf16/.cache/huggingface/download/tokenizer.json.lock
# 07:16:52.608 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/.cache/huggingface/download/.gitattributes.lock
# 07:16:52.896 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:16:52.897 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 464
# 07:16:52.898 aligo.INFO 文件秒传成功 /content/gpt-oss-20b-bf16/.cache/huggingface/download/.gitattributes.lock
# 07:16:52.899 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/.cache/huggingface/download/model-00003-of-00005.safetensors.lock
# 07:16:53.201 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:16:53.204 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 482
# 07:16:53.206 aligo.INFO 文件秒传成功 /content/gpt-oss-20b-bf16/.cache/huggingface/download/model-00003-of-00005.safetensors.lock
# 07:16:53.207 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/.cache/huggingface/download/config.json.lock
# 07:16:53.488 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:16:53.489 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 461
# 07:16:53.491 aligo.INFO 文件秒传成功 /content/gpt-oss-20b-bf16/.cache/huggingface/download/config.json.lock
# 07:16:53.492 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/.cache/huggingface/download/chat_template.jinja.lock
# 07:16:53.777 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:16:53.779 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 469
# 07:16:53.780 aligo.INFO 文件秒传成功 /content/gpt-oss-20b-bf16/.cache/huggingface/download/chat_template.jinja.lock
# 07:16:53.782 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/.cache/huggingface/download
aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 2996
#   0%|          | 0.00/125 [00:00<?, ?B/s]07:16:57.675 aligo.DEBUG https://cn-beijing-data.aliyundrive.net:443 "PUT /wYghzpn9%2F580097623%2F697b096842472b2ee4584eb199fd3e444b1da8e6%2F697b0968e63f4e63d6a24e6ba6d391e476a4c301?ap=pJZInNHN2dZWk8qg&di=bj29&dr=580097623&f=697b096842472b2ee4584eb199fd3e444b1da8e6&op=u&partNumber=1&pds-params=%7B%22ap%22%3A%22pJZInNHN2dZWk8qg%22%7D&security-token=CAISvgJ1q6Ft5B2yfSjIr5nSHfDRi7Jl2beYenzpnloNSrpWvK3qrDz2IHhMf3NpBOkZvvQ1lGlU6%2Fcalq5rR4QAXlDfNVuJXQD%2FqlHPWZHInuDox55m4cTXNAr%2BIhr%2F29CoEIedZdjBe%2FCrRknZnytou9XTfimjWFrXWv%2Fgy%2BQQDLItUxK%2FcCBNCfpPOwJms7V6D3bKMuu3OROY6Qi5TmgQ41Uh1jgjtPzkkpfFtkGF1GeXkLFF%2B97DRbG%2FdNRpMZtFVNO44fd7bKKp0lQLs0ARrv4r1fMUqW2X543AUgFLhy2KKMPY99xpFgh9a7j0iCbSGyUu%2FhcRm5sw9%2Byfo34lVYnew71A51bLbuHwufJ7FxfIREfquk63pvSlHLcLPe0Kjzzleo2k1XRPVFF%2B535IaHXuToXDnvSi%2Bw8DB%2FXtuMkagAFBbTAS99MZc6OvEYY%2BCM9JN1zHBPxz6qVmBRrmeCfSVOr7HrQSqkCOTe%2FHnHnDjH8%2Fy7CU9r1Upbw14nQMwYhfMv3DFw0w4OkLsuZB629dkKMdlq1Ffaq0QRL0YJ%2Bgh1uepnFYOypnrkxOKq%2B1752kbM6HLzmby%2F8PqMzByvanbiAA&u=e3e170d528284a56b5dce1b3fcd5f072&uploadId=022ED8848F374D678EE44C580E3B0A3D&x-oss-access-key-id=STS.NZgVJefmDnusxZXzZXF5zShAN&x-oss-expires=1769674617&x-oss-signature=ljb%2FmGyyyxIQfpC4MW6KaA8vxMciZqEqcwwKJ9E8efg%3D&x-oss-signature-version=OSS2 HTTP/1.1" 200 0
# 100%|██████████| 125/125 [00:00<00:00, 244B/s]
# 07:16:58.016 aligo.DEBUG https://api.aliyundrive.com:443 "POST /v2/file/complete HTTP/1.1" 200 None
# 07:16:58.017 aligo.INFO POST https://api.aliyundrive.com/v2/file/complete 200 1286
# 07:16:58.018 aligo.INFO 文件上传完成 /content/gpt-oss-20b-bf16/.cache/huggingface/download/model-00001-of-00005.safetensors.metadata
# 07:16:58.019 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/.cache/huggingface/download/tokenizer_config.json.lock
# 07:16:58.302 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:16:58.303 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 471
# 07:16:58.304 aligo.INFO 文件秒传成功 /content/gpt-oss-20b-bf16/.cache/huggingface/download/tokenizer_config.json.lock
# 07:16:58.304 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/.cache/huggingface/download/generation_config.json.lock
# 07:16:58.586 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:16:58.588 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 472
# 07:16:58.588 aligo.INFO 文件秒传成功 /content/gpt-oss-20b-bf16/.cache/huggingface/download/generation_config.json.lock
# 07:16:58.589 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/.cache/huggingface/download/model-00005-of-00005.safetensors.lock
# 07:16:58.875 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:16:58.876 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 482
# 07:16:58.877 aligo.INFO 文件秒传成功 /content/gpt-oss-20b-bf16/.cache/huggingface/download/model-00005-of-00005.safetensors.lock
# 07:16:58.878 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/.cache/huggingface/download/.gitattributes.metadata
# 07:16:59.175 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:16:59.176 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201
tuMkagAFBbTAS99MZc6OvEYY%2BCM9JN1zHBPxz6qVmBRrmeCfSVOr7HrQSqkCOTe%2FHnHnDjH8%2Fy7CU9r1Upbw14nQMwYhfMv3DFw0w4OkLsuZB629dkKMdlq1Ffaq0QRL0YJ%2Bgh1uepnFYOypnrkxOKq%2B1752kbM6HLzmby%2F8PqMzByvanbiAA&u=e3e170d528284a56b5dce1b3fcd5f072&uploadId=701118F020974B9EB4EC588507A2C877&x-oss-access-key-id=STS.NZgVJefmDnusxZXzZXF5zShAN&x-oss-expires=1769674623&x-oss-signature=8LPoqjVhN9j8ZK6s8X7zGLM%2BrXnOppVYrXrO3ifF5nY%3D&x-oss-signature-version=OSS2 HTTP/1.1" 200 0
# 100%|██████████| 101/101 [00:00<00:00, 356B/s]
# 07:17:04.673 aligo.DEBUG https://api.aliyundrive.com:443 "POST /v2/file/complete HTTP/1.1" 200 None
# 07:17:04.674 aligo.INFO POST https://api.aliyundrive.com/v2/file/complete 200 1265
# 07:17:04.676 aligo.INFO 文件上传完成 /content/gpt-oss-20b-bf16/.cache/huggingface/download/config.json.metadata
# 07:17:04.678 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/.cache/huggingface/.gitignore
# 07:17:04.999 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:17:05.001 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 455
# 07:17:05.002 aligo.INFO 文件秒传成功 /content/gpt-oss-20b-bf16/.cache/huggingface/.gitignore
# 07:17:05.003 aligo.INFO 开始上传文件 /content/gpt-oss-20b-bf16/model-00003-of-00005.safetensors
# 07:17:05.882 aligo.DEBUG https://api.aliyundrive.com:443 "POST /adrive/v2/file/createWithFolders HTTP/1.1" 201 None
# 07:17:06.121 aligo.INFO POST https://api.aliyundrive.com/adrive/v2/file/createWithFolders 201 1125467
#   0%|          | 0.00/4.57G [00:00<?, ?B/s]

# %%
# %%capture
import os, importlib.util
# !pip install --upgrade -qqq uv
if importlib.util.find_spec("torch") is None or "COLAB_" in "".join(os.environ.keys()):
    try: import numpy, PIL; get_numpy = f"numpy=={numpy.__version__}"; get_pil = f"pillow=={PIL.__version__}"
    except: get_numpy = "numpy"; get_pil = "pillow"
    # !uv pip install -qqq \
        "torch>=2.8.0" "triton>=3.4.0" {get_numpy} {get_pil} torchvision bitsandbytes "transformers==4.56.2" \
        "unsloth_zoo[base] @ git+https://github.com/unslothai/unsloth-zoo" \
        "unsloth[base] @ git+https://github.com/unslothai/unsloth" \
        git+https://github.com/triton-lang/triton.git@0add68262ab0a2e33b84524346cb27cbb2787356#subdirectory=python/triton_kernels
elif importlib.util.find_spec("unsloth") is None:
    # !uv pip install -qqq unsloth
# !uv pip install --upgrade --no-deps transformers==4.56.2 tokenizers trl==0.22.2 unsloth unsloth_zoo

# %% [markdown]
# ### Unsloth

# %% [markdown]
# We're about to demonstrate the power of the new OpenAI GPT-OSS 20B model through a finetuning example. To use our `MXFP4` inference example, use this [notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/GPT_OSS_MXFP4_(20B)-Inference.ipynb) instead.

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 1024
dtype = None

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/gpt-oss-20b-unsloth-bnb-4bit", # 20B model using bitsandbytes 4bit quantization
    "unsloth/gpt-oss-120b-unsloth-bnb-4bit",
    "unsloth/gpt-oss-20b", # 20B model using MXFP4 format
    "unsloth/gpt-oss-120b",
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/gpt-oss-20b",
    dtype = dtype, # None for auto detection
    max_seq_length = max_seq_length, # Choose any for long context!
    load_in_4bit = True,  # 4 bit quantization to reduce memory
    full_finetuning = False, # [NEW!] We have full finetuning now!
    # token = "hf_...", # use one if using gated models
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.1.4: Fast Gpt_Oss patching. Transformers: 4.56.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.5.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Using float16 precision for gpt_oss won't work! Using float32.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.37G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.16G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/165 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/27.9M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]

# %% [markdown]
# We now add LoRA adapters for parameter efficient finetuning - this allows us to only efficiently train 1% of all parameters.

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 8, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2851845322.py in <cell line: 0>()
# ----> 1 model = FastLanguageModel.get_peft_model(
#       2     model,
#       3     r=16,
#       4     target_modules=["q_proj", "k_proj", "v_proj", "o_proj",
#       5                     "gate_proj", "up_proj", "down_proj"],
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py in get_peft_model(model, r, target_modules, lora_alpha, lora_dropout, bias, layers_to_transform, layers_pattern, use_gradient_checkpointing, random_state, max_seq_length, use_rslora, modules_to_save, init_lora_weights, loftq_config, temporary_location, qat_scheme, ensure_weight_tying, **kwargs)
#    2667                 if peft_arg not in kwargs:
#    2668                     kwargs[peft_arg] = flag
# -> 2669             return FastBaseModel.get_peft_model(
#    2670                 model = model,
#    2671                 r = r,
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/vision.py in get_peft_model(model, r, target_modules, lora_alpha, lora_dropout, bias, finetune_vision_layers, finetune_language_layers, finetune_attention_modules, finetune_mlp_modules, layers_to_transform, layers_pattern, use_gradient_checkpointing, random_state, max_seq_length, use_rslora, modules_to_save, init_lora_weights, loftq_config, task_type, temporary_location, qat_scheme, ensure_weight_tying, **kwargs)
#     956
#     957         if isinstance(model, PeftModelForCausalLM):
# --> 958             raise RuntimeError(
#     959                 "Unsloth: You already added LoRA adapters to your model!"
#     960             )
#
# RuntimeError: Unsloth: You already added LoRA adapters to your model!

# %% [markdown]
# ### Reasoning Effort
# The `gpt-oss` models from OpenAI include a feature that allows users to adjust the model's "reasoning effort." This gives you control over the trade-off between the model's performance and its response speed (latency) which by the amount of token the model will use to think.
#
# ----
#
# The `gpt-oss` models offer three distinct levels of reasoning effort you can choose from:
#
# * **Low**: Optimized for tasks that need very fast responses and don't require complex, multi-step reasoning.
# * **Medium**: A balance between performance and speed.
# * **High**: Provides the strongest reasoning performance for tasks that require it, though this results in higher latency.

# %%
from transformers import TextStreamer

messages = [
    {"role": "user", "content": "Solve x^5 + 3x^4 - 10 = 3."},
]
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True,
    return_tensors = "pt",
    return_dict = True,
    reasoning_effort = "low", # **NEW!** Set reasoning effort to low, medium or high
).to("cuda")

_ = model.generate(**inputs, max_new_tokens = 64, streamer = TextStreamer(tokenizer))
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2026-01-28
#
# Reasoning: low
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>user<|message|>Solve x^5 + 3x^4 - 10 = 3.<|end|><|start|>assistant<|channel|>analysis<|message|>Equation: x^5 + 3x^4 - 10 = 3 => x^5 + 3x^4 -13=0. Solve for real roots. Maybe factor? try integer roots: try x=1:1+3-13=-9 no. x=2

# %% [markdown]
# Changing the `reasoning_effort` to `medium` will make the model think longer. We have to increase the `max_new_tokens` to occupy the amount of the generated tokens but it will give better and more correct answer

# %%
from transformers import TextStreamer

messages = [
    {"role": "user", "content": "Solve x^5 + 3x^4 - 10 = 3."},
]
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True,
    return_tensors = "pt",
    return_dict = True,
    reasoning_effort = "medium", # **NEW!** Set reasoning effort to low, medium or high
).to("cuda")

_ = model.generate(**inputs, max_new_tokens = 64, streamer = TextStreamer(tokenizer))
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2026-01-28
#
# Reasoning: medium
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>user<|message|>Solve x^5 + 3x^4 - 10 = 3.<|end|><|start|>assistant<|channel|>analysis<|message|>The user asks: "Solve x^5 + 3x^4 - 10 = 3." Probably solve for x? So equation: x^5 + 3x^4 - 10 = 3. Move 3: x^5 + 3x^4 -

# %% [markdown]
# Lastly we will test it using `reasoning_effort` to `high`

# %%
from transformers import TextStreamer

messages = [
    {"role": "user", "content": "Solve x^5 + 3x^4 - 10 = 3."},
]
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True,
    return_tensors = "pt",
    return_dict = True,
    reasoning_effort = "high", # **NEW!** Set reasoning effort to low, medium or high
).to("cuda")

_ = model.generate(**inputs, max_new_tokens = 64, streamer = TextStreamer(tokenizer))
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-08-13
#
# Reasoning: high
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>user<|message|>Solve x^5 + 3x^4 - 10 = 3.<|end|><|start|>assistant<|channel|>analysis<|message|>We need to solve the equation: x^5 + 3x^4 - 10 = 3. Or maybe it's x^5 + 3x^4 - 10 = 3? That seems like a polynomial equation: x^5 + 3x^4 - 10

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep

# %% [markdown]
# The `HuggingFaceH4/Multilingual-Thinking` dataset will be utilized as our example. This dataset, available on Hugging Face, contains reasoning chain-of-thought examples derived from user questions that have been translated from English into four other languages. It is also the same dataset referenced in OpenAI's [cookbook](https://cookbook.openai.com/articles/gpt-oss/fine-tune-transfomers) for fine-tuning. The purpose of using this dataset is to enable the model to learn and develop reasoning capabilities in these four distinct languages.

# %%
from datasets import load_dataset
from trl import GRPOConfig, GRPOTrainer
import re

print("Loading GSM8K dataset...")

dataset = load_dataset("openai/gsm8k", "main", split="train[:1000]")

def format_math_prompt(examples):
    prompts = []

    for question in examples["question"]:
        prompt = f"""Solve this math problem step by step:

Problem: {question}

Solution:"""
        prompts.append(prompt)

    return {
        "prompt": prompts,
        "answer": examples["answer"]
    }

print("Formatting prompts...")

dataset = dataset.map(format_math_prompt, batched=True, remove_columns=["question"])
# Out:
# Loading GSM8K dataset...
# README.md: 0.00B [00:00, ?B/s]
# main/train-00000-of-00001.parquet:   0%|          | 0.00/2.31M [00:00<?, ?B/s]
# main/test-00000-of-00001.parquet:   0%|          | 0.00/419k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7473 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1319 [00:00<?, ? examples/s]
# Formatting prompts...
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %% [markdown]
# To format our dataset, we will apply our version of the GPT OSS prompt

# %%
def compute_math_reward(prompts, completions, completion_ids, **kwargs):
    answers = kwargs.get('answers', None)

    rewards = []

    for i, completion in enumerate(completions):
        try:
            pred_numbers = re.findall(r'-?\d+\.?\d*', completion)

            if answers and i < len(answers):
                true_numbers = re.findall(r'-?\d+\.?\d*', answers[i])

                if pred_numbers and true_numbers:
                    pred_final = float(pred_numbers[-1])
                    true_final = float(true_numbers[-1])

                    if abs(pred_final - true_final) < 0.01:
                        rewards.append(1.0)
                    else:
                        rewards.append(-0.5)
                else:
                    rewards.append(-1.0)
            else:
                if pred_numbers:
                    rewards.append(0.1)
                else:
                    rewards.append(-1.0)

        except Exception:
            rewards.append(-1.0)

    return torch.tensor(rewards, dtype=torch.float32)

# %% [markdown]
# Let's take a look at the dataset, and check what the 1st example shows

# %%
grpo_config = GRPOConfig(
    output_dir="./grpo_math_outputs",
    num_train_epochs=2,
    max_steps=500,

    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,

    learning_rate=5e-6,
    lr_scheduler_type="cosine",
    warmup_steps=50,

    num_generations=4,
    max_completion_length=512,
    temperature=0.7,
    top_p=0.9,

    optim="adamw_8bit",
    weight_decay=0.01,
    max_grad_norm=1.0,

    logging_steps=10,
    save_steps=100,
    save_total_limit=2,

    bf16=True,

    seed=3407,
    report_to="none",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-687207165.py in <cell line: 0>()
# ----> 1 grpo_config = GRPOConfig(
#       2     output_dir="./grpo_math_outputs",
#       3     num_train_epochs=2,
#       4     max_steps=500,
#       5
#
# /content/unsloth_compiled_cache/UnslothGRPOTrainer.py in __init__(self, output_dir, overwrite_output_dir, do_train, do_eval, do_predict, eval_strategy, prediction_loss_only, per_device_train_batch_size, per_device_eval_batch_size, per_gpu_train_batch_size, per_gpu_eval_batch_size, gradient_accumulation_steps, eval_accumulation_steps, eval_delay, torch_empty_cache_steps, learning_rate, weight_decay, adam_beta1, adam_beta2, adam_epsilon, max_grad_norm, num_train_epochs, max_steps, lr_scheduler_type, warmup_ratio, warmup_steps, log_level, log_level_replica, log_on_each_node, logging_dir, logging_strategy, logging_first_step, logging_steps, logging_nan_inf_filter, save_strategy, save_steps, save_total_limit, save_safetensors, save_on_each_node, save_only_model, restore_callback_states_from_checkpoint, no_cuda, use_cpu, use_mps_device, seed, data_seed, jit_mode_eval, use_ipex, bf16, fp16, fp16_opt_level, half_precision_backend, bf16_full_eval, fp16_full_eval, tf32, local_rank, ddp_backend, tpu_num_cores, tpu_metrics_debug, debug, dataloader_drop_last, eval_steps, dataloader_num_workers, dataloader_prefetch_factor, past_index, run_name, disable_tqdm, remove_unused_columns, label_names, load_best_model_at_end, metric_for_best_model, greater_is_better, ignore_data_skip, fsdp, fsdp_min_num_params, fsdp_config, fsdp_transformer_layer_cls_to_wrap, accelerator_config, parallelism_config, deepspeed, label_smoothing_factor, optim, optim_args, adafactor, group_by...
#    1559
#    1560
# -> 1561         super().__init__(
#    1562             output_dir = output_dir,
#    1563             overwrite_output_dir = overwrite_output_dir,
#
# /usr/local/lib/python3.12/dist-packages/trl/trainer/grpo_config.py in __init__(self, output_dir, overwrite_output_dir, do_train, do_eval, do_predict, eval_strategy, prediction_loss_only, per_device_train_batch_size, per_device_eval_batch_size, per_gpu_train_batch_size, per_gpu_eval_batch_size, gradient_accumulation_steps, eval_accumulation_steps, eval_delay, torch_empty_cache_steps, learning_rate, weight_decay, adam_beta1, adam_beta2, adam_epsilon, max_grad_norm, num_train_epochs, max_steps, lr_scheduler_type, lr_scheduler_kwargs, warmup_ratio, warmup_steps, log_level, log_level_replica, log_on_each_node, logging_dir, logging_strategy, logging_first_step, logging_steps, logging_nan_inf_filter, save_strategy, save_steps, save_total_limit, save_safetensors, save_on_each_node, save_only_model, restore_callback_states_from_checkpoint, no_cuda, use_cpu, use_mps_device, seed, data_seed, jit_mode_eval, use_ipex, bf16, fp16, fp16_opt_level, half_precision_backend, bf16_full_eval, fp16_full_eval, tf32, local_rank, ddp_backend, tpu_num_cores, tpu_metrics_debug, debug, dataloader_drop_last, eval_steps, dataloader_num_workers, dataloader_prefetch_factor, past_index, run_name, disable_tqdm, remove_unused_columns, label_names, load_best_model_at_end, metric_for_best_model, greater_is_better, ignore_data_skip, fsdp, fsdp_min_num_params, fsdp_config, fsdp_transformer_layer_cls_to_wrap, accelerator_config, parallelism_config, deepspeed, label_smoothing_factor, opti...
#
# /usr/local/lib/python3.12/dist-packages/trl/trainer/grpo_config.py in __post_init__(self)
#     604         self.bf16 = not (self.fp16) if self.bf16 is None else self.bf16
#     605
# --> 606         super().__post_init__()
#     607
#     608         self.scale_rewards = {True: "group", False: "none"}.get(self.scale_rewards, self.scale_rewards)
#
# /usr/local/lib/python3.12/dist-packages/transformers/training_args.py in __post_init__(self)
#    1737                             error_message += " You need Ampere+ GPU with cuda>=11.0"
#    1738                         # gpu
# -> 1739                         raise ValueError(error_message)
#    1740
#    1741         if self.fp16 and self.bf16:
#
# ValueError: Your setup doesn't support bf16/gpu. You need Ampere+ GPU with cuda>=11.0

# %% [markdown]
# What is unique about GPT-OSS is that it uses OpenAI [Harmony](https://github.com/openai/harmony) format which support conversation structures, reasoning output, and tool calling.

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's train our model. We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`.

# %%
from trl import SFTConfig, SFTTrainer
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    args = SFTConfig(
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        # num_train_epochs = 1, # Set this for 1 full training run.
        max_steps = 30,
        learning_rate = 2e-4,
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.001,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # Use TrackIO/WandB etc
    ),
)
# Out:
# Unsloth: Switching to float32 training since model cannot work with float16
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/1000 [00:00<?, ? examples/s]

# %% [markdown]
# We also use Unsloth's `train_on_completions` method to only train on the assistant outputs and ignore the loss on the user's inputs. This helps increase accuracy of finetunes and lower loss as well!

# %%
from unsloth.chat_templates import train_on_responses_only

gpt_oss_kwargs = dict(instruction_part = "<|start|>user<|message|>", response_part="<|start|>assistant<|channel|>final<|message|>")

trainer = train_on_responses_only(
    trainer,
    **gpt_oss_kwargs,
)

# %% [markdown]
# Let's verify masking the instruction part is done! Let's print the 100th row again.

# %%
tokenizer.decode(trainer.train_dataset[100]["input_ids"])

# %% [markdown]
# Now let's print the masked out example - you should see only the answer is present:

# %%
tokenizer.decode([tokenizer.pad_token_id if x == -100 else x for x in trainer.train_dataset[100]["labels"]]).replace(tokenizer.pad_token, " ")

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.741 GB.
# 12.811 GB of memory reserved.

# %% [markdown]
# Let's train the model! To resume a training run, set `trainer.train(resume_from_checkpoint = True)`

# %%
trainer_stats = trainer.train()
# Out:
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# The tokenizer has new special tokens that are also defined in the model configs. The model configs were aligned accordingly. Updated tokens: {'bos_token_id': 199998, 'pad_token_id': 200017}
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,000 | Num Epochs = 1 | Total steps = 30
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 4 x 1) = 4
#  "-____-"     Trainable parameters = 3,981,312 of 20,918,738,496 (0.02% trained)
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 08:34, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.130500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.918100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.419300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.167900</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.978200</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.119900</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.825800</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.703400</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.974400</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.796700</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.698900</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.637100</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.633600</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.570100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.418700</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.643800</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.697200</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.830000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.386500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.400800</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.329000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.382800</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.504600</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.589200</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.400000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.431400</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.465200</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.468800</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.421100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.408200</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 645.6936 seconds used for training.
# 10.76 minutes used for training.
# Peak reserved memory = 12.975 GB.
# Peak reserved memory for training = 0.164 GB.
# Peak reserved memory % of max memory = 88.02 %.
# Peak reserved memory for training % of max memory = 1.113 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!

# %%
messages = [
    {"role": "system", "content": "reasoning language: French\n\nYou are a helpful assistant that can solve mathematical problems."},
    {"role": "user", "content": "Solve x^5 + 3x^4 - 10 = 3."},
]
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True,
    return_tensors = "pt",
    return_dict = True,
    reasoning_effort = "medium",
).to("cuda")
from transformers import TextStreamer
_ = model.generate(**inputs, max_new_tokens = 64, streamer = TextStreamer(tokenizer))
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-08-13
#
# Reasoning: medium
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>developer<|message|># Instructions
#
# reasoning language: French
#
# You are a helpful assistant that can solve mathematical problems.<|end|><|start|>user<|message|>Solve x^5 + 3x^4 - 10 = 3.<|end|><|start|>assistant<|channel|>analysis<|message|>The equation is \(x^5 + 3x^4 - 10 = 3\), or \(x^5 + 3x^4 - 13 = 0\). So we need to find the roots of \(x^5 + 3x^4 - 13

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** Currently finetunes can only be loaded via Unsloth in the meantime - we're working on vLLM and GGUF exporting!

# %%
model.save_pretrained("finetuned_model")
# model.push_to_hub("hf_username/finetuned_model", token = "hf_...") # Save to HF

# %% [markdown]
# To run the finetuned model, you can do the below after setting `if False` to `if True` in a new instance.

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "finetuned_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = 1024,
        dtype = None,
        load_in_4bit = True,
    )

messages = [
    {"role": "system", "content": "reasoning language: French\n\nYou are a helpful assistant that can solve mathematical problems."},
    {"role": "user", "content": "Solve x^5 + 3x^4 - 10 = 3."},
]
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True,
    return_tensors = "pt",
    return_dict = True,
    reasoning_effort = "high",
).to("cuda")
from transformers import TextStreamer
_ = model.generate(**inputs, max_new_tokens = 64, streamer = TextStreamer(tokenizer))
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-08-13
#
# Reasoning: high
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>developer<|message|># Instructions
#
# reasoning language: French
#
# You are a helpful assistant that can solve mathematical problems.<|end|><|start|>user<|message|>Solve x^5 + 3x^4 - 10 = 3.<|end|><|start|>assistant<|channel|>analysis<|message|>We need to solve the equation for x. The equation: x^5 + 3x^4 - 10 = 3. So bring 3 to left side: x^5 + 3x^4 -10 -3 = 0 → x^5 + 3x^

# %% [markdown]
# ### Saving to float16 for VLLM or mxfp4
#
# We also support saving to `float16` or `mxfp4` directly. Select `merged_16bit` for float16. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge and push to hub in mxfp4 4bit format
if False:
    model.save_pretrained_merged("finetuned_model", tokenizer, save_method = "mxfp4")
if False: model.push_to_hub_merged("repo_id/repo_name", tokenizer, token = "hf...", save_method = "mxfp4")

# Merge and push to hub in 16bit
if False:
    model.save_pretrained_merged("finetuned_model", tokenizer, save_method = "merged_16bit")
if False: # Pushing to HF Hub
    model.push_to_hub_merged("hf/gpt-oss-finetune", tokenizer, save_method = "merged_16bit", token = "")

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
#
#   This notebook and all Unsloth notebooks are licensed [LGPL-3.0](https://github.com/unslothai/notebooks?tab=LGPL-3.0-1-ov-file#readme).
